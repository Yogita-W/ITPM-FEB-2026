# %% [markdown]
# Type Casting in python.

# %%
x = 2 #int
y = 3.5 # float
print(x+y) #5.5
# Out:
# 5.5

# %%
Name = "Vedant" # str
Age = 22 #int
print(Name + Age) #Vedant 22
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 Name = "Vedant"
#       2 Age = 22
# ----> 3 print(Name + Age) #Vedant 22
#
# TypeError: can only concatenate str (not "int") to str

# %%
Name = "Vedant" # str
Age = str(22) #int
print(Name +" "+ Age)
# Out:
# Vedant 22

# %% [markdown]
# 1.Implicite Data Type :
# 1.int
# 2.float
# 3.complex
# 4.bool

# %%
#1.int+float
x = 10
y = 20.5
print(x+y)
# Out:
# 30.5

# %%
#int+complex
x = 10
z = 10+3j
print(x+z)
# Out:
# (20+3j)

# %%
#int+bool
x=10
B = True
print(x+B)
# Out:
# 11

# %%
# int to str 
Age = 20
n_age = str(20)
print(Age,type(Age))
print(n_age,type(n_age))
# Out:
# 20 <class 'int'>
# 20 <class 'str'>

# %%
#int+str
Name = "Mayur" #str
Marks = 90 # int
print(Name+str(Marks))
# Out:
# Mayur90

# %%
#list to set
l1 = [1,2,3,4,5]
s1 = set(l1)
print(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
#wap to remove duplicates from give list.
l1 = [1,2,3,1,2,1,1,1]
nw_l1 = set(l1)
out_l1 = list(nw_l1)
print(nw_l1)
print(out_l1)
# Out:
# {1, 2, 3}
# [1, 2, 3]

# %%
l1 = [1,2,3,1,2,1,1,1]
print(list(set(l1)))
# Out:
# [1, 2, 3]

# %% [markdown]
# Explisite - Type casting
# 1.string
# 2.list
# 3.Set
# 4.Tuple
# 5.Dict

# %% [markdown]
# list to set
# list to tuple
# list to set
# list to dict
#
# set : set to list,set to tuple,set to dict
# tuple:
# dict :
#
# WAp take list,set,dict,tuple values dynamically.

# %%
#list to tuple
l1 = [1,2,3,4,5]
t1 = tuple(l1)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
#dict to list
dict = {101:"Itpm Python",
        "Domain" : "Python"}
list1 = list(dict)
print(list1)
# Out:
# [101, 'Domain']

# %%
#Wap to print keys name from give dict.
dict1 = {"Name" : ["Tushar","Krushna","Vedant"],
         "Marks" : [22,34,54],
         "Address " : ["Pune","Mumbai"]}
s1 = set(dict1)
s1
# Out:
# {'Address ', 'Marks', 'Name'}

# %% [markdown]
# Different Ways to print stat.

# %%
x = 10
y = 20
print(x)
print(y)
# Out:
# 10
# 20

# %%
x = 10
y = 20
print(x,y)
# Out:
# 10 20

# %%
x = 10
y = 20
print("x value =", x)
# Out:
# x value = 10

# %%
x = 10
y = 20
print(f"x value = {x}")
# Out:
# x value = 10

# %%
Name = "Darshan"
Address = "Pune"
print(f"My name is {Name} and am from {Address}")
# Out:
# My name is Darshan and am from Pune

# %%
Name = "Darshan"
Address = "Pune"
print(f"My name is {Name} \nam from {Address}")
# Out:
# My name is Darshan
# am from Pune

# %%
#take x value from user.
x = input("Enter a number")
print(x)
# Out:
# 20

# %%
y =int(input("Enter int value"))
print(y)
# Out:
# 10

# %%
x = int(input("Enter a number"))
y = float(input("Enter a second number"))
print(x+y)
print(".............................................................." )
print(f"value of x :{x}\nvalue of y:{y} \nAddition of x and y {x+y}")
# Out:
# 30.5
# ..............................................................
# value of x :10
# value of y:20.5
# Addition of x and y 30.5

# %%
l1 = list(input("enter list"))
print(l1)
print(type(l1))
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9']
# <class 'list'>

# %%
l1 = list(int(input("enter list")))
print(l1)
print(type(l1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 l1 = list(int(input("enter list")))
#       2 print(l1)
#       3 print(type(l1))
#
# TypeError: 'int' object is not iterable
