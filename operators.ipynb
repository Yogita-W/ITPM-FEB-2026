# %%
x = 6
y = 10
print(x+y) # 16
print(x-y) # -4
print(x*y)
# Out:
# 16
# -4
# 60

# %%
print(x/y) # 0.6
print(x%y) # 6
print(x**y) # 6**10
print(2**3)
# Out:
# 0.6
# 6
# 60466176
# 8

# %%
x = 12
y = 10
print(x//y)
print(x/y)
# Out:
# 1
# 1.2

# %% [markdown]
# Comp.
# 1.==
# 2.!=
# 3.>
# 4.<
# 5.>=
# 6.<=

# %%
x = 10
y = 20
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x<=y)
print(x>=y)
# Out:
# False
# True
# False
# True
# True
# False

# %% [markdown]
# 3.Logical
# 1.AND
# 2.OR
# 3.NOT
#
# Logical Table for and or not if we have 2 conditions.
#
# cond1  cond2  AND  OR NOT(COND1)
# T       T      T   T    F
# T       F      F   T    F
# F       T      F   T    T
# F       F      F   F    T

# %%
X = 10
Y = 20
print(x>10 and y>10)
print(x>10 or y>10)
# Out:
# False
# True

# %% [markdown]
# 4.Membership operators :
# 1.in
# 2.not in

# %%
l1 = [1,2,3,4]
print(4 in l1)
# Out:
# True

# %%
name = ["Tushar","Prathmesh","Tejas","Sania","onkar"]
print("Tejas" in name)
print("Tejas" not in name)
# Out:
# True
# False

# %% [markdown]
# 5.Identity operators.
# 1.is
# 2.is not

# %%
x = 5
y = 5
print( x is y)
# Out:
# True

# %%
#what is difference between is and ==.
x = 10
y = 10
print(x==y) # == checks values
print(x is y)# is checks mem.location

# %%
# is not 
a = 10
b = 20
print(a is not b)
# Out:
# True

# %%
l1 = [1,2,3,4,5]
l2 = [1,3,2,4,5]
print(l1 is l2)
# Out:
# False

# %%
s1 = {1,2,3,4,5}
s2 = {1,3,4,2,5}
print(s1 is s2)
# Out:
# False

# %% [markdown]
# 6.Assignment oper.
# 1.=
# 2.+=
# 3.-=
# 4.*=
# 5./=
# 6.%=
# 7.//=

# %%
x1 = 10
x1+=1
print(x1)
# Out:
# 11

# %%
x = 10
x-=1
print(x)
# Out:
# 9

# %%
y = 20
y*=3
print(y)
# Out:
# 60

# %%
y = 20
y/=3
print(y)
# Out:
# 6.666666666666667

# %%
y1 =200
y//=5
print(y)
# Out:
# 1.0

# %%
a1 = 2
a1**=2
print(a1)
# Out:
# 4

# %% [markdown]
# 7.bit-wise operators:
#   1.& : if both the bits are 1 it'll print 1 otherwise it'll print 0
#   2.| : if one of the bit among all it'll print 1
#   3.^ : if only one bit is 1 it'll print 1
#   4.>> :
#   5.<< :

# %% [markdown]
# 1st 2nd  or ex-or
# 1    1   1    0
# 1    0   1    1
# 0    1   1    1
# 0    0   0    0

# %%
x = 1 #  01
y = 2 # 10
# 01
# 10
#................
# 00................dec 0
print(x & y)
# Out:
# 0

# %%
a = 10 #
b = 15 #
print(a&b)
print(a|b)
# Out:
# 10
# 15

# %%
a = 20
b = 26
print(a&b)
print(a|b)
print(a^b)
# Out:
# 16
# 30
# 14

# %%
x = 4
# 4 bin 0100
#       0010 2
#       1000 ........8
print(x>>1)
print(x<<1)
print(~x)
# x = +100
#      +  1
#............
# Out:
# 2
# 8
# -5
