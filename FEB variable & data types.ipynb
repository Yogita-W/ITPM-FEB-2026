# %% [markdown]
# VARIABLES IN PYTHON

# %%
''' IN C LANG.
INT X = 5 
INT = DATA TYPE
X VARIABLE
5 IS VALUES ''' 
 
 # IN PYTHON VARIABLE DEC 
X = 5 
name = 'Vedant'

# %%
#variable Declaration in python
Name = "Vedant"
Marks = 90
Domain = "AI/ML"
print(Name,Marks,Domain)
# Out:
# Vedant 90 AI/ML

# %% [markdown]
# Variable Naming Rules :
# 1.

# %%
# lowecase
name = "Abc"
print(name)
# Out:
# Abc

# %%
#uppercase
NAME = "XYZ"
NAME
# Out:
# 'XYZ'

# %%
#combination of low & upper ,numbers
Mark123 = 345
print(Mark123)
# Out:
# 345

# %%
# variable space Not allowed.
full_Name ="abcd"
full_Name

# %%
#Number not allowed as variable name.
1 = "Python"
1Name = "xyz"

# %%
Age = 30
print(age)

# %%
Name$@ = "abc"
Name$@

# %%
else = " cbja"
print(else))
# Out:
#   Cell In[10], line 2
#     print(else))
#                ^
# SyntaxError: unmatched ')'

# %%
#name should be Meaningful
ikfhrkjfgjrmfgkerufyikeufhil = 23
ikfhrkjfgjrmfgkerufyikeufhil
# Out:
# 23

# %%
#starting with _ allowed
_Name = "abc"
_Name
# Out:
# 'abc'

# %% [markdown]
# Different Way to Assign Value to Variable.

# %%
#1.common way to Assign value to variable
x = 4
y = 5
print(x,y)
# Out:
# 4 5

# %%
#2.Multiple variables in single line
x = y = 20
print(x,y)
# Out:
# 20 20

# %%
a = 10
a = 20
print(a)
# Out:
# 20

# %%
x,y = 10,20
print(x,y)
# Out:
# 10 20

# %%
A = 10
def number(xa1):

# %%
print(A)
# Out:
# 10

# %% [markdown]
# Data Types in Python.
# 1.Number 1.Int
#          2.float
#          3.complex
# 2.String

# %%
x = 12 #int
y = 10.5 #float

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x = 2+3j
print(x)
print(type(x))
# Out:
# (2+3j)
# <class 'complex'>

# %%
#string
Name = 'Tushar'
Name1 = "Tushar"
Name2 = '''Tushar'''
print(Name,Name1,Name2)
# Out:
# Tushar Tushar Tushar

# %%
Stu_Info = 'Vedant 50' 
Info = "I am Tejas am learning Python my batch name is Itpm  2025 #"
x = '5'
print(type(x))
# Out:
# <class 'str'>

# %%
#List : hetro,mutable,duplicate,order collection of elements. 
l1 = [1,2,3,4] #int list
#hetro : different types of elements.
l1 = [1,2,3,5.7,5.2,"Python"]
print(l1)
print(type(l1))
# Out:
# [1, 2, 3, 5.7, 5.2, 'Python']
# <class 'list'>

# %%
#list is mutable in nature.
l1 = [1,2,3,4]
print(l1)
# Out:
# [1, 2, 3, 4]

# %%
l1.append(5)
print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
#duplicate
l2 = [1,2,2,3,1,4]
print(l2)
# Out:
# [1, 2, 2, 3, 1, 4]

# %%
#List is ordered in nature.
l1 = [1,2,3,4,5]
l2 = [1,2,4,3,5]
print(l1==l2)
# Out:
# False

# %% [markdown]
# Tuple : it is Similar to list but immutable in nature.
# tuple : ex : t1 = (1,2,3)

# %%
t1 = (1,2,3,4)
t1
# Out:
# (1, 2, 3, 4)

# %%
#tuple is immutable
t1.append(5)
t1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 t1.append(5)
#       2 t1
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#Duplicate,ordered,hetro.
t2 = (1,2,2,2,2,2)
print(t2)
t3 = (1,2,3,4,5)
t4 = (1,2,4,5,3)
print(t3==t4)
t5 = (1,2,3,"ITpm","Python",4.5,[1,2,3,4])
print(t5)
# Out:
# (1, 2, 2, 2, 2, 2)
# False
# (1, 2, 3, 'ITpm', 'Python', 4.5, [1, 2, 3, 4])

# %% [markdown]
# Set : set is collection of herto,duplicates not allowed,unordered in nature.
# ex : set s1 = {}

# %%
s1 = {1,2,3,4,5}
print(s1)
print(type(s1))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
s2 = {1,2,3,"Python","UI",3.4}
s2
# Out:
# {1, 2, 3, 3.4, 'Python', 'UI'}

# %%
s3 = {1,2,3,2,2,1,1,1,1}
s3
# Out:
# {1, 2, 3}

# %%
#un-ordered collection of elements
s1 = {1,2,3,4,5}
s2 = {1,2,4,5,3}
print(s1==s2)
# Out:
# True

# %%
# set is mutable in nature.
set1 = {23,43,32,21}
set1.add(22)
print(set1)
# Out:
# {32, 43, 21, 22, 23}

# %%
Dict : Collection keys and values.
dict ex: d1 = {101:"Mayur"
}}

# %%
dict1 = {"Name":["Krushna","Tushar","Kartik","onkar"],
         "Id":[1,2,3,4,5]}
dict1
# Out:
# {'Name': ['Krushna', 'Tushar', 'Kartik', 'onkar'], 'Id': [1, 2, 3, 4, 5]}

# %% [markdown]
# boolean

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>
